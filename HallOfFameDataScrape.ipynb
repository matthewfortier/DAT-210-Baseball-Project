# %%
from lxml import html
import time
import requests
import pandas as pd

# %%
page = requests.get("http://www.hallofstats.com/")
tree = html.fromstring(page.content)

# %%
names = tree.xpath('//ol[@id="player-list"]//strong/text()')
warValues = tree.xpath('//ol[@id="player-list"]//span/text()')

# %%
names = [n.replace('\n', '') for n in names]
warValues = [n.replace('\n', '') for n in war]

# %%
hallOfFameDictionary = dict(zip(names, warValues))

# %%
#Easier to put the two lists into dataframe instead of dictionary, since the dictionary loses the ordering
df = pd.DataFrame({'Name': names, 'WAR': warValues})
df
# Out:
#                  Name  WAR
# 0           Babe Ruth  399
# 1         Barry Bonds  362
# 2      Walter Johnson  337
# 3            Cy Young  336
# 4         Willie Mays  336
# 5             Ty Cobb  319
# 6          Hank Aaron  296
# 7       Roger Clemens  294
# 8      Rogers Hornsby  289
# 9        Honus Wagner  284
# 10       Tris Speaker  280
# 11       Ted Williams  279
# 12        Stan Musial  263
# 13      Eddie Collins  253
# 14     Pete Alexander  251
# 15     Alex Rodriguez  245
# 16         Lou Gehrig  241
# 17      Mickey Mantle  238
# 18        Lefty Grove  233
# 19   Rickey Henderson  231
# 20        Kid Nichols  230
# 21         Nap Lajoie  227
# 22       Mike Schmidt  227
# 23            Mel Ott  226
# 24         Tom Seaver  220
# 25        Greg Maddux  220
# 26      Randy Johnson  219
# 27          Cap Anson  215
# 28     Frank Robinson  211
# 29      Albert Pujols  211
# ..                ...  ...
# 471       Jesse Crain   27
# 472       Brett Myers   27
# 473    Miguel Batista   26
# 474     Brian Fuentes   25
# 475         Adam Dunn   25
# 476      Nick Johnson   25
# 477    Jeremy Affeldt   25
# 478     Carlos Marmol   25
# 479    Jose Contreras   25
# 480       Scott Downs   25
# 481       Jeff Suppan   24
# 482        Mike Adams   24
# 483        Nick Punto   24
# 484       Juan Pierre   24
# 485        David Ross   24
# 486        Brad Lidge   23
# 487     Jair Jurrjens   23
# 488     Sean Marshall   23
# 489     Dickey Pearce   22
# 490        Luis Ayala   22
# 491     Austin Kearns   22
# 492       Paul Maholm   22
# 493      Lyle Overbay   22
# 494      Ryan Ludwick   21
# 495       J.C. Romero   21
# 496    Jake Westbrook   21
# 497        Bruce Chen   21
# 498   Michael Cuddyer   21
# 499     Mike Gonzalez   20
# 500    Jerry Hairston   20
#
# [501 rows x 2 columns]

# %%
df.to_csv("Hall_of_Fame.csv", sep=",", index=False)
